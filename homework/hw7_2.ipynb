# %%
from sage.misc.prandom import randrange
from sage.plot.point import point
from sage.plot.polygon import Polygon
from sage.plot.line import Line
p0=polygon([(0,0),(0,200),(200,200),(200,0)],fill=False)
p0
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('N')
N=randrange(0,25)
print(N)
x=[randrange(200) for i in range(N)]
y=[randrange(200) for i in range(N)]
n=zip(x,y)
print(n)
p1=points(n,size=12,color='green')
(p0+p1).show()
# Out:
# 13
# ...
# Graphics object consisting of 2 graphics primitives

# %%
m=randrange(N)
o= (x[m],y[m])
print(o)
# Out:
# (27, 133)

# %%
a=[0 for i in range(50)]
for i in range(50):
    for j in range(N):
        for k in range(N):
            if(k!=j):
                d=((x[k]-x[j])^2+((y[k]-y[j]))^2)^(1/2)
            if(k==j):
                d=0                
            if(d<((i+1)*10)):
                a[i]=a[i]+1
b=[(i+1)*10 for i in range(50)]
c=[a[i]/(pi*(i+1)^2) for i in range(50)]
d=[a[i] for i in range(50)]
v=zip(b,c)
f1=line(v)
f1.show()
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1.show()
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# for large N, curve is smooth and it gets rougher, with lower value of n
