# %% [markdown]
# Homework 8

# %% [markdown]
# [Q1]Determine the points of extrema (minima, maxima) and the points of inflection for the following curve. Visualize the same using plot

# %%
A=x**3-20*x
A.show()
# Out:
# x^3 - 20*x

# %%
s=plot(A, -10, 10, ymin=-100, ymax=100)
s.show()
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
B=A.diff()

# %%
[f1,f2]=B.solve(x)
f1
# Out:
# x == -2/3*sqrt(5)*sqrt(3)

# %%
find_root(B,-100,0)
# Out:
# -2.581988897471611

# %%
C=A.diff(2)
C.show()
# Out:
# 6*x

# %%
a=C(f1.rhs())
a.show()
# Out:
# -4*sqrt(5)*sqrt(3)

# %%
b=C(f2.rhs())
b.show()
# Out:
# 4*sqrt(5)*sqrt(3)

# %%
find_local_minimum(A, -5, 5)
# Out:
# (-34.426518632954824, 2.5819888976160383)

# %%
find_local_maximum(A, -5, 5)
# Out:
# (34.42651863295482, -2.5819888976667733)

# %% [markdown]
# Here using find_local ... we have verified our result
# Also note the output is (A(x),x)

# %% [markdown]
# As f1 and f2 are solutions of A'==0; they are extrema
# Therefore using the double derivative test
# f1 has negative double derivative and is hence a maxima
# f2 has positive double derivative and is hence a minima

# %% [markdown]
# [Q3]
# Determine the solution of the following equation: -x +cosx Show that the solution is the intersection of the plots of the following two functions graphically.
#     x,cosx

# %%
F(x)=-x+cos(x)
Fsol=F(x).solve(x)
print(Fsol)
# Out:
# [
# x == cos(x)
# ]

# %%
find_root(F(x),0,2)
# Out:
# 0.7390851332151607

# %%
plot(x,ymin=-4,ymax=4,color='red')+ plot(cos(x),-5,5,color='red')+plot(x-cos(x),-5,5,color='green')+line([(0.7390851332151607,0),(0.7390851332151607,0.7390851332151607)])
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# We use find_root to find the root in our range
# then by plotting the graphs of x, cosx and x-cosx we compare to prove intersection of x and cos x is the sameas the zero of x-cosx
