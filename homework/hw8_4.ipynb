# %% [markdown]
# [Q2] Pick a function from the assignments of your other courses and determine the limits using sage

# %%
p=(e^(1/(x**2+x))-x)
p.show()
# Out:
# -x + e^(1/(x^2 + x))

# %%
p.plot(-4,4,ymin=-2,ymax=6)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
sage: p.limit(x=0)
# Out:
# und

# %%
p.limit(x=-1/2)
# Out:
# 1/2*(e^4 + 2)*e^(-4)

# %%
p.limit(x=4.4)
# Out:
# -3.3570142200931925

# %%
p2=x*cos(1/x)
p2.plot()
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
p2.limit(x=0)
# Out:
# 0

# %%
p2.limit(x=pi)
# Out:
# pi*cos(1/pi)

# %%
p3=(4*x**2-1)**(1/2)/(2*x+1)
p3.plot()
# Out:
# verbose 0 (3698: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 100 points.
# verbose 0 (3698: plot.py, generate_plot_points) Last error message: 'math domain error'
# Graphics object consisting of 2 graphics primitives

# %%
p3.limit(x=-1/2)
# Out:
# Infinity

# %%
p3.limit(x=1)
# Out:
# 0.5773502691896257

# %%
p3.limit(x=Infinity)
# Out:
# 1

# %%
p3.limit(x=-Infinity)
# Out:
# -1
