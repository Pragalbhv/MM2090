# %% [markdown]
# Hypotrochoid

# %%
parametric_plot([3*cos(t) + 4* cos(t/6), 3*sin(t) - 4 * sin(t/6)], (t,0, 12*pi), fill = True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
parametric_plot([6*cos(t) + 4* cos(t/6), 6*sin(t) - 4 * sin(t/6)], (t,0, 12*pi), fill = True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
parametric_plot([2*cos(t) + 4* cos(t/6), 2*sin(t) - 4 * sin(t/6)], (t,0, 12*pi), fill = True)
# Out:
# Graphics object consisting of 2 graphics primitives
